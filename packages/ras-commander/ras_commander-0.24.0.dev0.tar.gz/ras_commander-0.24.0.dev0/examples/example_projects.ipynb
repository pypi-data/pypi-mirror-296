# %% [markdown]
# # Notebook for running all the examples in the examples folder
#
# This notebook also serves as a test of the ras_commander package using the HEC-RAS Project Examples provided by HEC.
#
# Example project names can be found in the example_projects.csv file after the examples are run.
#
# To use a different example, change the project name in the examples and run them directly or run this notebook.

# %% [markdown]
# The notebook format provides a convenient way to run all the examples to ensure that no features are broken after code revisions.

# %% [markdown]
# -----

# %% [markdown]
# This table is a valuable reference for formulating examples and anticipating script behavior.
#
# | Project           | Type     | Existing Numbers | Next Available |
# |-------------------|----------|-------------------|----------------|
# | Balde Eagle Creek | Plan     | 01, 02            | 03             |
# |                   | Flow     | 01, 02            | 03             |
# |                   | Unsteady | 02                | 01, 03         |
# |                   | Geometry | 01                | 02             |
# | Muncie            | Plan     | 01, 03, 04        | 02, 05         |
# |                   | Flow     | 01                | 02             |
# |                   | Unsteady | 01                | 02             |
# |                   | Geometry | 01, 02, 04        | 03, 05         |
#
# Notes:
# 1. For Balde Eagle Creek's Unsteady entries, 01 is available before 03. The library should use the lowest available number when creating new entries.
# 2. For Muncie's Plan entries, both 02 and 05 are available. The library should use 02 first.
# 3. For Muncie's Geometry entries, 03 is available before 05.
#
# When writing examples or scripts:
# 1. Use existing numbers when referencing current plans, flows, unsteady setups, or geometries.
# 2. When creating new entries (e.g., cloning), use the "Next Available" number and then increment for subsequent creations.
# 3. After operations that create new entries, verify that the ras object has been updated to reflect these changes.
#
# This approach will help ensure that examples run as expected and that we're always working with valid, up-to-date data in our scripts.

# %% [markdown]
# -----

# %% [markdown]
# # RAS-Commander (ras_commander) library examples

# %% [markdown]
# ### The Examples Below Have Been Tested and Verified.

# %% [markdown]
# -----

# %%
#!pip install pandas pathlib requests

# %%
# Example 1: Import and execute 01_project_initialization.py
print("Executing 01_project_initialization.py:")
# %run 01_project_initialization.py
print("\n")
# Out:
# Executing 01_project_initialization.py:
# Example projects folder: c:\GH\ras-commander_workspace\examples\example_projects
# Found zip file: c:\GH\ras-commander_workspace\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Balde Eagle Creek'
# Project 'Balde Eagle Creek' already exists. Deleting existing folder...
# Existing folder for project 'Balde Eagle Creek' has been deleted.
# Successfully extracted project 'Balde Eagle Creek' to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek
# ----- RasExamples Extracting Project -----
# Extracting project 'BaldEagleCrkMulti2D'
# Successfully extracted project 'BaldEagleCrkMulti2D' to c:\GH\ras-commander_workspace\examples\example_projects\BaldEagleCrkMulti2D
# ----- RasExamples Extracting Project -----
# Extracting project 'Muncie'
# Successfully extracted project 'Muncie' to c:\GH\ras-commander_workspace\examples\example_projects\Muncie
# Example Set 1: Using the default global 'ras' object
# -----------------------------------------------------
# Step 1: Initializing with global RAS instance
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
#
# --- Data for BaldEagle ---
# Project folder: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek
# PRJ file: C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.prj
# HEC-RAS executable: C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe
#
# Plan files:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
#
# Flow files:
#   flow_number                                          full_path
# 0          02  c:\GH\ras-commander_workspace\examples\example...
# 1          01  c:\GH\ras-commander_workspace\examples\example...
#
# Unsteady flow files:
#   unsteady_number                                          full_path
# 0              02  c:\GH\ras-commander_workspace\examples\example...
#
# Geometry files:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
#
# HDF entries:
# Empty DataFrame
# Columns: [plan_number, full_path, HDF_Results_Path]
# Index: []
# ----------------------------
#
#
# Step 2: Demonstrating accessing specific data
# Global RAS instance (Bald Eagle Creek) first plan file:
# plan_number                                                        01
# full_path           c:\GH\ras-commander_workspace\examples\example...
# HDF_Results_Path                                                 None
# Name: 0, dtype: object
#
# Step 3: Accessing All RAS Object Data
# Project Name: BaldEagle
# Project Folder: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek
# PRJ File: C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.prj
# HEC-RAS Executable Path: C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe
#
# Plan Files DataFrame:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
#
# Flow Files DataFrame:
#   flow_number                                          full_path
# 0          02  c:\GH\ras-commander_workspace\examples\example...
# 1          01  c:\GH\ras-commander_workspace\examples\example...
#
# Unsteady Flow Files DataFrame:
#   unsteady_number                                          full_path
# 0              02  c:\GH\ras-commander_workspace\examples\example...
#
# Geometry Files DataFrame:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
#
# HDF Entries DataFrame:
# Empty DataFrame
# Columns: [plan_number, full_path, HDF_Results_Path]
# Index: []
#
# Example Set 2: Using custom ras objects
# -----------------------------------------------------
# Step 1: Initializing multiple project instances
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagleDamBrk-----
# Plan entries: 11, Flow entries: 0, Unsteady entries: 10, Geometry entries: 10
#
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: Muncie-----
# Plan entries: 3, Flow entries: 1, Unsteady entries: 1, Geometry entries: 3
#
#
# Multi2D project data:
#
# --- Data for Muncie ---
# Project folder: c:\GH\ras-commander_workspace\examples\example_projects\Muncie
# PRJ file: C:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.prj
# HEC-RAS executable: C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe
#
# Plan files:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          03  c:\GH\ras-commander_workspace\examples\example...
# 2          04  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
# 2             None
#
# Flow files:
#   flow_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
#
# Unsteady flow files:
#   unsteady_number                                          full_path
# 0              01  c:\GH\ras-commander_workspace\examples\example...
#
# Geometry files:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          04  c:\GH\ras-commander_workspace\examples\example...
#
# HDF entries:
# Empty DataFrame
# Columns: [plan_number, full_path, HDF_Results_Path]
# Index: []
# ----------------------------
#
#
# Muncie project data:
#
# --- Data for Muncie ---
# Project folder: c:\GH\ras-commander_workspace\examples\example_projects\Muncie
# PRJ file: C:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.prj
# HEC-RAS executable: C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe
#
# Plan files:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          03  c:\GH\ras-commander_workspace\examples\example...
# 2          04  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
# 2             None
#
# Flow files:
#   flow_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
#
# Unsteady flow files:
#   unsteady_number                                          full_path
# 0              01  c:\GH\ras-commander_workspace\examples\example...
#
# Geometry files:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          04  c:\GH\ras-commander_workspace\examples\example...
#
# HDF entries:
# Empty DataFrame
# Columns: [plan_number, full_path, HDF_Results_Path]
# Index: []
# ----------------------------
#
#
# Step 2: Accessing specific data from custom ras objects
# Multi2D project first geometry file:
# geom_number                                                   01
# full_path      c:\GH\ras-commander_workspace\examples\example...
# Name: 0, dtype: object
#
# Muncie project first unsteady flow file:
# unsteady_number                                                   01
# full_path          c:\GH\ras-commander_workspace\examples\example...
# Name: 0, dtype: object
#
# Step 3: Accessing All RAS Object Data for Multi2D Project
# Project Name: Muncie
# Project Folder: c:\GH\ras-commander_workspace\examples\example_projects\Muncie
# PRJ File: C:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.prj
# HEC-RAS Executable Path: C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe
#
# Plan Files DataFrame:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          03  c:\GH\ras-commander_workspace\examples\example...
# 2          04  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
# 2             None
#
# Flow Files DataFrame:
#   flow_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
#
# Unsteady Flow Files DataFrame:
#   unsteady_number                                          full_path
# 0              01  c:\GH\ras-commander_workspace\examples\example...
#
# Geometry Files DataFrame:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          04  c:\GH\ras-commander_workspace\examples\example...
#
# HDF Entries DataFrame:
# Empty DataFrame
# Columns: [plan_number, full_path, HDF_Results_Path]
# Index: []
#
# Example of simplified import (not recommended for complex scripts)
# -----------------------------------------------------
# from ras_commander import *
# # This allows you to use all functions and classes without prefixes
# # For example: compute_plan() instead of RasCmdr.compute_plan()
# # Note: This approach can lead to naming conflicts and is generally not recommended for larger scripts

# %% [markdown]
# -----

# %%
import time

# wait 10 seconds
time.sleep(10)

# %%
# Example 2: Import and execute 02_plan_operations.py
print("Executing 02_plan_operations.py:")
# %run 02_plan_operations.py
print("\n")
# Out:
# Executing 02_plan_operations.py:
# Example projects folder: c:\GH\ras-commander_workspace\examples\example_projects
# Found zip file: c:\GH\ras-commander_workspace\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Balde Eagle Creek'
# Project 'Balde Eagle Creek' already exists. Deleting existing folder...
# Existing folder for project 'Balde Eagle Creek' has been deleted.
# Successfully extracted project 'Balde Eagle Creek' to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Initial plan files:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
#
# Step 1: Cloning a plan
# Copied c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p01 to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
# Updated short identifier in c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
# Updated C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.prj with new plan p03
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 3, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# New plan created: 03
# Updated plan files:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
# 2             None
#
# Step 2: Cloning a geometry
# Copied 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g01' to 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g02'.
# Copied 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g01.hdf' to 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g02.hdf'.
# Updated C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.prj with new geometry file g02
# Updated geometry entries:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# New geometry created: 02
# Updated geometry files:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
#
# Step 3: Cloning an unsteady flow
# Copied c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.u02 to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.u01
# Copied c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.u02.hdf to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.u01.hdf
# Updated C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.prj with new unsteady flow file u01
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 3, Flow entries: 2, Unsteady entries: 2, Geometry entries: 2
#
# New unsteady flow created: 01
# Updated unsteady flow files:
#   unsteady_number                                          full_path
# 0              01  c:\GH\ras-commander_workspace\examples\example...
# 1              02  c:\GH\ras-commander_workspace\examples\example...
#
# Step 4: Setting geometry for a plan
# Current geometry DataFrame within the function:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# Geometry for plan 03 set to 02
# Updated plan DataFrame:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path geom_number
# 0             None         NaN
# 1             None         NaN
# 2             None          02
# Updated project file with new geometry for plan 03
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 3, Flow entries: 2, Unsteady entries: 2, Geometry entries: 2
#
# Updated geometry for plan 03
# Plan file path: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
#
# Step 5: Setting unsteady flow for a plan
# Setting unsteady flow file from 01 to 03
# Updated unsteady flow file in c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p03 to u01
# Updated unsteady flow for plan 03
#
# Step 6: Setting the number of cores for a plan
# Setting num_cores to 2 in Plan 03
# Updated c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p03 with 2 cores.
# Updated number of cores for plan 03
#
# Step 7: Setting geometry preprocessor options
# Reading the file: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
# Updating the file with new settings...
# Updated 'Run HTab' to -1
# Updated 'UNET Use Existing IB Tables' to -1
# Writing the updated settings back to the file: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
# File update completed successfully.
# Updated geometry preprocessor options for plan 03
# Step 8: Computing the cloned plan
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p03"
# HEC-RAS execution completed for plan: 03
# Total run time for plan 03: 128.65 seconds
# Computing plan 03
# Plan 03 computed successfully
#
# Step 9: Retrieving HDF entries for the cloned plan
# HDF entries for the cloned plan:
#   plan_number                                          full_path  \
# 2          03  c:\GH\ras-commander_workspace\examples\example...
#
#                                     HDF_Results_Path
# 2  c:\GH\ras-commander_workspace\examples\example...
#
# Current plan entries:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
#
#                                     HDF_Results_Path
# 0                                               None
# 1                                               None
# 2  c:\GH\ras-commander_workspace\examples\example...

# %% [markdown]
# -----

# %%
# wait 10 seconds
time.sleep(10)

# %%
# Example 3: Import and execute 03_geometry_operations.py
print("Executing 03_geometry_operations.py:")
# %run 03_geometry_operations.py
print("\n")
# Out:
# Executing 03_geometry_operations.py:
# Example projects folder: c:\GH\ras-commander_workspace\examples\example_projects
# Found zip file: c:\GH\ras-commander_workspace\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Muncie'
# Project 'Muncie' already exists. Deleting existing folder...
# Existing folder for project 'Muncie' has been deleted.
# Successfully extracted project 'Muncie' to c:\GH\ras-commander_workspace\examples\example_projects\Muncie
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: Muncie-----
# Plan entries: 3, Flow entries: 1, Unsteady entries: 1, Geometry entries: 3
#
# Initial plan files:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          03  c:\GH\ras-commander_workspace\examples\example...
# 2          04  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
# 2             None
#
# Step 1: Cloning a plan
# Copied c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p01 to c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p02
# Updated short identifier in c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p02
# Updated C:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.prj with new plan p02
#
# -----Initialization complete for project: Muncie-----
# Plan entries: 4, Flow entries: 1, Unsteady entries: 1, Geometry entries: 3
#
# New plan created: 02
# Updated plan files:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
# 2             None
# 3             None
#
# Step 2: Cloning a geometry file and assigning it to the cloned plan
# Copied 'c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.g01' to 'c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.g03'.
# Copied 'c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.g01.hdf' to 'c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.g03.hdf'.
# Updated C:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.prj with new geometry file g03
# Updated geometry entries:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
# New geometry created: 03
# Now set the new geometry to the new plan
# Current geometry DataFrame within the function:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
# Geometry for plan 02 set to 03
# Updated plan DataFrame:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path geom_number
# 0             None         NaN
# 1             None          03
# 2             None         NaN
# 3             None         NaN
# Updated project file with new geometry for plan 02
#
# -----Initialization complete for project: Muncie-----
# Plan entries: 4, Flow entries: 1, Unsteady entries: 1, Geometry entries: 4
#
# New geometry 03 assigned to plan 02
# Updated geometry files:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
#
# Step 3: Clearing geometry preprocessor files for the cloned plan
# No geometry preprocessor file found for: c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p02
# Cleared geometry preprocessor files for plan 02
#
# Step 4: Clearing geometry preprocessor files for all plans
# Clearing all geometry preprocessor files in the project directory.
# No geometry preprocessor file found for: c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p01
# No geometry preprocessor file found for: c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p02
# No geometry preprocessor file found for: c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p03
# No geometry preprocessor file found for: c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p04
# No geometry preprocessor file found for: c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.prj
# Cleared geometry preprocessor files for all plans
#
# Step 5: Updated plan information
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
# 2             None
# 3             None
#
# Step 6: Computing the cloned plan
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.prj" "c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p02"
# HEC-RAS execution completed for plan: 02
# Total run time for plan 02: 24.34 seconds
# Computing plan 02
# Plan 02 computed successfully
#
# Step 7: Getting results paths
# Plan DataFrame:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
#
#                                     HDF_Results_Path
# 0                                               None
# 1  c:\GH\ras-commander_workspace\examples\example...
# 2                                               None
# 3                                               None
# Results file for Plan number 02 exists at: c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p02.hdf
# Results for plan 02 are located at: c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p02.hdf
# Plan DataFrame:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
#
#                                     HDF_Results_Path
# 0                                               None
# 1  c:\GH\ras-commander_workspace\examples\example...
# 2                                               None
# 3                                               None
# Results file for Plan number 01 does not exist.
# No results found for plan 01

# %% [markdown]
# -----

# %%
# wait 10 seconds
time.sleep(10)

# %%
# Example 4: Import and execute 04_unsteady_flow_operations.py
print("Executing 04_unsteady_flow_operations.py:")
# %run 04_unsteady_flow_operations.py
print("\n")
# Out:
# Executing 04_unsteady_flow_operations.py:
# Example projects folder: c:\GH\ras-commander_workspace\examples\example_projects
# Found zip file: c:\GH\ras-commander_workspace\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Balde Eagle Creek'
# Project 'Balde Eagle Creek' already exists. Deleting existing folder...
# Existing folder for project 'Balde Eagle Creek' has been deleted.
# Successfully extracted project 'Balde Eagle Creek' to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Initial plan files:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
#
# Step 1: Cloning a plan
# Copied c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p01 to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
# Updated short identifier in c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
# Updated C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.prj with new plan p03
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 3, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# New plan created: 03
# Updated plan files:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
# 2             None
#
# Step 3: Updating unsteady flow parameters individually
# Updated Simulation Date to 01JAN2023,0000,05JAN2023,2400
# Applied modifications to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
# Updated Computation Interval to 1MIN
# Applied modifications to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
# Updated Output Interval to 15MIN
# Applied modifications to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
# Updated parameters individually
#
# Step 4: Updating unsteady flow parameters in batch
# Updated Mapping Interval to 30MIN
# Applied modifications to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
# Updated parameters in batch
#
# Step 5: Verifying changes
# Updated Simulation Date=01JAN2023,0000,05JAN2023,2400
# Updated Computation Interval=1MIN
# Updated Output Interval=15MIN
# Updated Mapping Interval=30MIN
#
# Step 6: Computing the updated plan
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p03"
# HEC-RAS execution completed for plan: 03
# Total run time for plan 03: 149.27 seconds
# Plan 03 computed successfully

# %% [markdown]
# -----

# %%
# wait 10 seconds
time.sleep(10)

# %%
# Example 5: Import and execute 05_utility_functions.py
print("Executing 05_utility_functions.py:")
# %run 05_utility_functions.py
print("\n")
# Out:
# Executing 05_utility_functions.py:
# Example projects folder: c:\GH\ras-commander_workspace\examples\example_projects
# Found zip file: c:\GH\ras-commander_workspace\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Balde Eagle Creek'
# Project 'Balde Eagle Creek' already exists. Deleting existing folder...
# Existing folder for project 'Balde Eagle Creek' has been deleted.
# Successfully extracted project 'Balde Eagle Creek' to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Example 1: Getting plan path
# Path for plan 01 is: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p01
#
# Example 2: Getting geometry path
# Path for geometry 01 is: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g01
#
# Example 3: Getting unsteady flow path
# Unsteady number 01 not found in the updated unsteady entries.
# Path for unsteady flow 01 is: None
#
# Example 4: Getting project name
# Project name: BaldEagle

# %% [markdown]
# -----

# %%
# wait 10 seconds
time.sleep(10)

# %%
# Example 6: Import and execute 06_single_plan_execution.py
print("Executing 06_single_plan_execution.py:")
# %run 06_single_plan_execution.py
print("\n")
# Out:
# Executing 06_single_plan_execution.py:
# Example projects folder: c:\GH\ras-commander_workspace\examples\example_projects
# Found zip file: c:\GH\ras-commander_workspace\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Balde Eagle Creek'
# Successfully extracted project 'Balde Eagle Creek' to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Available plans:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
#
# Example 1: Executing a single plan
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p01"
# HEC-RAS execution completed for plan: 01
# Total run time for plan 01: 166.20 seconds
# Plan 01 executed successfully
#
# Example 2: Executing a plan in a separate destination folder
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\compute_test_2\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\compute_test_2\BaldEagle.p02"
# HEC-RAS execution completed for plan: 02
# Total run time for plan 02: 7.33 seconds
# Plan 02 executed successfully in c:\GH\ras-commander_workspace\examples\example_projects\compute_test_2
#
# Example 3: Getting results path
# Plan DataFrame:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
#
#                                     HDF_Results_Path
# 0  c:\GH\ras-commander_workspace\examples\example...
# 1                                               None
# Results file for Plan number 02 does not exist.
# No results found for plan 02
#
# Example 4: Executing a plan with cleared geometry preprocessor files
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Plan number 03 not found in the updated plan entries.
# Error: Could not find project file or plan file for plan 03
# Plan 03 execution failed
#
# Example 5: Executing a plan with a specified number of cores, overwriting compute_test_3
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Setting num_cores to 2 in Plan c:\GH\ras-commander_workspace\examples\example_projects\compute_test_3\BaldEagle.p01
# Updated c:\GH\ras-commander_workspace\examples\example_projects\compute_test_3\BaldEagle.p01 with 2 cores.
# Set number of cores to 2 for plan: 01
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\compute_test_3\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\compute_test_3\BaldEagle.p01"
# HEC-RAS execution completed for plan: 01
# Total run time for plan 01: 24.15 seconds
# Plan 01 executed successfully using 2 cores
#
# Example 6: Executing a plan with all new options combined
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# No geometry preprocessor file found for: c:\GH\ras-commander_workspace\examples\example_projects\compute_test_all_options\BaldEagle.p02
# Cleared geometry preprocessor files for plan: 02
# Setting num_cores to 4 in Plan c:\GH\ras-commander_workspace\examples\example_projects\compute_test_all_options\BaldEagle.p02
# Updated c:\GH\ras-commander_workspace\examples\example_projects\compute_test_all_options\BaldEagle.p02 with 4 cores.
# Set number of cores to 4 for plan: 02
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\compute_test_all_options\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\compute_test_all_options\BaldEagle.p02"
# HEC-RAS execution completed for plan: 02
# Total run time for plan 02: 7.80 seconds
# Plan 02 executed successfully with all options:
# - Destination folder: c:\GH\ras-commander_workspace\examples\example_projects\compute_test_all_options
# - Cleared geometry preprocessor files
# - Used 4 cores

# %% [markdown]
# -----

# %%
# wait 10 seconds
time.sleep(10)

# %%
# Example 7: Import and execute 07_sequential_plan_execution.py
print("Executing 07_sequential_plan_execution.py:")
# %run 07_sequential_plan_execution.py
print("\n")
# Out:
# Executing 07_sequential_plan_execution.py:
# Removing existing folder: C:\GH\ras-commander_workspace\examples\example_projects
# Example projects folder: c:\GH\ras-commander_workspace\examples\example_projects
# Found zip file: c:\GH\ras-commander_workspace\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Balde Eagle Creek'
# Successfully extracted project 'Balde Eagle Creek' to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Available plans:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
#
# Example 1: Sequential execution of all plans with overwrite_dest
# Starting the compute_test_mode...
# Creating the test folder: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [AllSequential]...
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Getting plan entries...
# Retrieved plan entries successfully.
# Running selected plans sequentially...
# Error computing plan 01: name 'RasCommander' is not defined
# Total run time for plan 01: 0.00 seconds
# Error computing plan 02: name 'RasCommander' is not defined
# Total run time for plan 02: 0.00 seconds
# All selected plans have been executed.
# compute_test_mode completed.
# Sequential execution of all plans completed with overwrite_dest
#
# Example 2: Sequential execution of specific plans with clearing geompre files and overwrite_dest
# Starting the compute_test_mode...
# Creating the test folder: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [SpecificSequentialClearGeompre]...
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Getting plan entries...
# Retrieved plan entries successfully.
# Filtered plans to execute: ['01', '02']
# Running selected plans sequentially...
# Error computing plan 01: name 'RasCommander' is not defined
# Total run time for plan 01: 0.00 seconds
# Error computing plan 02: name 'RasCommander' is not defined
# Total run time for plan 02: 0.00 seconds
# All selected plans have been executed.
# compute_test_mode completed.
# Sequential execution of specific plans completed with clearing geompre files and overwrite_dest
#
# Example 3: Clearing geompre files for specific plans
# No geometry preprocessor file found for: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p01
# No geometry preprocessor file found for: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p02
# Geometry preprocessor files cleared for specific plans
#
# Example 4: Clearing all geompre files
# Clearing all geometry preprocessor files in the project directory.
# No geometry preprocessor file found for: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p01
# No geometry preprocessor file found for: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p01.computeMsgs.txt
# No geometry preprocessor file found for: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p01.comp_msgs.txt
# No geometry preprocessor file found for: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p02
# No geometry preprocessor file found for: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p02.computeMsgs.txt
# No geometry preprocessor file found for: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.prj
# All geometry preprocessor files cleared

# %% [markdown]
# -----

# %%
# wait 10 seconds
time.sleep(10)

# %%
# Example 8: Import and execute 08_parallel_execution.py
print("Executing 08_parallel_execution.py:")
# %run 08_parallel_execution.py
print("\n")
# Out:
# Executing 08_parallel_execution.py:
# Example projects folder: c:\GH\ras-commander_workspace\examples\example_projects
# Found zip file: c:\GH\ras-commander_workspace\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Balde Eagle Creek'
# Project 'Balde Eagle Creek' already exists. Deleting existing folder...
# Existing folder for project 'Balde Eagle Creek' has been deleted.
# Successfully extracted project 'Balde Eagle Creek' to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Available plans:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
#
# Example 1: Parallel execution of all plans with overwrite_dest
# Adjusted max_workers to 2 based on the number of plans: 2
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Worker 1 executing plan 01
# Setting num_cores to 2 in Plan c:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel [Worker 1]\BaldEagle.p01
# Worker 2 executing plan 02
# Setting num_cores to 2 in Plan c:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel [Worker 2]\BaldEagle.p02
# Updated c:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel [Worker 1]\BaldEagle.p01 with 2 cores.
# Updated c:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel [Worker 2]\BaldEagle.p02 with 2 cores.
# Set number of cores to 2 for plan: 01
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel [Worker 1]\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel [Worker 1]\BaldEagle.p01"
# Set number of cores to 2 for plan: 02
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel [Worker 2]\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel [Worker 2]\BaldEagle.p02"
# HEC-RAS execution completed for plan: 02
# Total run time for plan 02: 7.81 seconds
# Completed: Plan 02 in worker 2
# HEC-RAS execution completed for plan: 01
# Total run time for plan 01: 135.91 seconds
# Completed: Plan 01 in worker 1
# Final destination for computed results: c:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel
# Error moving results from c:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel [Worker 1] to c:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\GH\\ras-commander_workspace\\examples\\example_projects\\compute_test_parallel [Worker 1]'
#
# Execution Results:
# Plan 02: Successful
# Plan 01: Successful
# Parallel execution of all plans results:
# Plan 02: Successful
# Plan 01: Successful
#
# Example 2: Parallel execution of specific plans with overwrite_dest
# Adjusted max_workers to 2 based on the number of plans: 2
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Worker 1 executing plan 01
# Worker 2 executing plan 02
# Setting num_cores to 2 in Plan c:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel_specific [Worker 2]\BaldEagle.p02
# Setting num_cores to 2 in Plan c:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel_specific [Worker 1]\BaldEagle.p01
# Updated c:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel_specific [Worker 2]\BaldEagle.p02 with 2 cores.
# Updated c:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel_specific [Worker 1]\BaldEagle.p01 with 2 cores.
# Set number of cores to 2 for plan: 02
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel_specific [Worker 2]\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel_specific [Worker 2]\BaldEagle.p02"
# Set number of cores to 2 for plan: 01
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel_specific [Worker 1]\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel_specific [Worker 1]\BaldEagle.p01"
# HEC-RAS execution completed for plan: 02
# Total run time for plan 02: 9.89 seconds
# Completed: Plan 02 in worker 2
# HEC-RAS execution completed for plan: 01
# Total run time for plan 01: 151.72 seconds
# Completed: Plan 01 in worker 1
# Final destination for computed results: c:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel_specific
# Error moving results from c:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel_specific [Worker 1] to c:\GH\ras-commander_workspace\examples\example_projects\compute_test_parallel_specific: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\GH\\ras-commander_workspace\\examples\\example_projects\\compute_test_parallel_specific [Worker 1]'
#
# Execution Results:
# Plan 02: Successful
# Plan 01: Successful
# Parallel execution of specific plans results:
# Plan 02: Successful
# Plan 01: Successful
#
# Example 3: Getting results paths
# Plan DataFrame:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
# Results file for Plan number 01 does not exist.
# No results found for plan 01
# Plan DataFrame:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
# Results file for Plan number 02 does not exist.
# No results found for plan 02

# %% [markdown]
# -----

# %%
# wait 10 seconds
time.sleep(10)

# %%
# Example 9: Import and execute 09_specifying_plans.py
print("Executing 09_specifying_plans.py:")
# %run 09_specifying_plans.py
print("\n")
# Out:
# Executing 09_specifying_plans.py:
# Removing existing folder: C:\GH\ras-commander_workspace\examples\example_projects
# Example projects folder: c:\GH\ras-commander_workspace\examples\example_projects
# Found zip file: c:\GH\ras-commander_workspace\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Balde Eagle Creek'
# Successfully extracted project 'Balde Eagle Creek' to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Available plans:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
#
# Example 1: Sequential execution of specific plans (1 and 3)
# Starting the compute_test_mode...
# Creating the test folder: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [SpecificSequential]...
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Getting plan entries...
# Retrieved plan entries successfully.
# Filtered plans to execute: ['01', '03']
# Running selected plans sequentially...
# Error computing plan 01: name 'RasCommander' is not defined
# Total run time for plan 01: 0.00 seconds
# All selected plans have been executed.
# compute_test_mode completed.
# Sequential execution of specific plans completed
#
# Example 2: Parallel execution of specific plans
# Adjusted max_workers to 2 based on the number of plans: 2
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Worker 1 executing plan 01
# Worker 2 executing plan 02
# Setting num_cores to 2 in Plan c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 1]\BaldEagle.p01
# Setting num_cores to 2 in Plan c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 2]\BaldEagle.p02
# Updated c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 1]\BaldEagle.p01 with 2 cores.
# Updated c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 2]\BaldEagle.p02 with 2 cores.
# Set number of cores to 2 for plan: 01
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 1]\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 1]\BaldEagle.p01"
# Set number of cores to 2 for plan: 02
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 2]\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 2]\BaldEagle.p02"
# HEC-RAS execution completed for plan: 02
# Total run time for plan 02: 10.36 seconds
# Completed: Plan 02 in worker 2
# HEC-RAS execution completed for plan: 01
# Total run time for plan 01: 137.01 seconds
# Completed: Plan 01 in worker 1
# Final destination for computed results: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Computed]
# Error moving results from c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 1] to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Computed]: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\GH\\ras-commander_workspace\\examples\\example_projects\\Balde Eagle Creek [Worker 1]'
#
# Execution Results:
# Plan 02: Successful
# Plan 01: Successful
# Parallel execution of specific plans results:
# Plan 02: Successful
# Plan 01: Successful
#
# Example 3: Execute all plans
# Starting the compute_test_mode...
# Creating the test folder: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [AllPlans]...
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Getting plan entries...
# Retrieved plan entries successfully.
# Filtered plans to execute: ['01', '02']
# Running selected plans sequentially...
# Error computing plan 01: name 'RasCommander' is not defined
# Total run time for plan 01: 0.00 seconds
# Error computing plan 02: name 'RasCommander' is not defined
# Total run time for plan 02: 0.00 seconds
# All selected plans have been executed.
# compute_test_mode completed.
# Execution of all plans completed

# %% [markdown]
# -----

# %%
# wait 10 seconds
time.sleep(10)

# %%
print("Executing 10_arguments_for_compute.py:")
# %run 10_arguments_for_compute.py
print("\n")
# Out:
# Executing 10_arguments_for_compute.py:
# Example projects folder: c:\GH\ras-commander_workspace\examples\example_projects
# Found zip file: c:\GH\ras-commander_workspace\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Balde Eagle Creek'
# Project 'Balde Eagle Creek' already exists. Deleting existing folder...
# Existing folder for project 'Balde Eagle Creek' has been deleted.
# Successfully extracted project 'Balde Eagle Creek' to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Available plans:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
#
# Example 1: Sequential execution with various arguments
# Starting the compute_test_mode...
# Creating the test folder: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek _01_[SequentialWithArgs]...
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Getting plan entries...
# Retrieved plan entries successfully.
# Filtered plans to execute: ['01']
# Running selected plans sequentially...
# Error computing plan 01: name 'RasCommander' is not defined
# Total run time for plan 01: 0.00 seconds
# All selected plans have been executed.
# compute_test_mode completed.
# Plan 01 execution: Failed
# Starting the compute_test_mode...
# Creating the test folder: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek _02_[SequentialWithArgs]...
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Getting plan entries...
# Retrieved plan entries successfully.
# Filtered plans to execute: ['02']
# Running selected plans sequentially...
# Error computing plan 02: name 'RasCommander' is not defined
# Total run time for plan 02: 0.00 seconds
# All selected plans have been executed.
# compute_test_mode completed.
# Plan 02 execution: Failed
# Sequential execution completed
#
# Starting the compute_test_mode...
# Creating the test folder: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek _02_[SequentialWithArgs]...
# If the example operates successfully (it is meant to generate an error above), you will not see this message.
# Example 2: Parallel execution with various arguments
# Adjusted max_workers to 2 based on the number of plans: 2
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Worker 1 executing plan 01
# Worker 2 executing plan 02
# No geometry preprocessor file found for: c:\GH\ras-commander_workspace\examples\example_projects\parallel_results [Worker 1]\BaldEagle.p01
# No geometry preprocessor file found for: c:\GH\ras-commander_workspace\examples\example_projects\parallel_results [Worker 2]\BaldEagle.p02
# Cleared geometry preprocessor files for plan: 01
# Setting num_cores to 2 in Plan c:\GH\ras-commander_workspace\examples\example_projects\parallel_results [Worker 1]\BaldEagle.p01
# Cleared geometry preprocessor files for plan: 02
# Setting num_cores to 2 in Plan c:\GH\ras-commander_workspace\examples\example_projects\parallel_results [Worker 2]\BaldEagle.p02
# Updated c:\GH\ras-commander_workspace\examples\example_projects\parallel_results [Worker 1]\BaldEagle.p01 with 2 cores.
# Updated c:\GH\ras-commander_workspace\examples\example_projects\parallel_results [Worker 2]\BaldEagle.p02 with 2 cores.
# Set number of cores to 2 for plan: 01
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\parallel_results [Worker 1]\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\parallel_results [Worker 1]\BaldEagle.p01"
# Set number of cores to 2 for plan: 02
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\parallel_results [Worker 2]\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\parallel_results [Worker 2]\BaldEagle.p02"
# HEC-RAS execution completed for plan: 02
# Total run time for plan 02: 9.78 seconds
# Completed: Plan 02 in worker 2
# HEC-RAS execution completed for plan: 01
# Total run time for plan 01: 149.76 seconds
# Completed: Plan 01 in worker 1
# Final destination for computed results: c:\GH\ras-commander_workspace\examples\example_projects\parallel_results
# Error moving results from c:\GH\ras-commander_workspace\examples\example_projects\parallel_results [Worker 1] to c:\GH\ras-commander_workspace\examples\example_projects\parallel_results: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\GH\\ras-commander_workspace\\examples\\example_projects\\parallel_results [Worker 1]'
#
# Execution Results:
# Plan 02: Successful
# Plan 01: Successful
# Parallel execution results:
# Plan 02: Successful
# Plan 01: Successful
#
# Example 3: Single plan execution with specific arguments
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# No geometry preprocessor file found for: c:\GH\ras-commander_workspace\examples\example_projects\compute_test_2\BaldEagle.p02
# Cleared geometry preprocessor files for plan: 02
# Setting num_cores to 2 in Plan c:\GH\ras-commander_workspace\examples\example_projects\compute_test_2\BaldEagle.p02
# Updated c:\GH\ras-commander_workspace\examples\example_projects\compute_test_2\BaldEagle.p02 with 2 cores.
# Set number of cores to 2 for plan: 02
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\compute_test_2\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\compute_test_2\BaldEagle.p02"
# HEC-RAS execution completed for plan: 02
# Total run time for plan 02: 9.22 seconds
# Single plan execution: Successful

# %%
# wait 10 seconds
time.sleep(10)

# %%
print("Executing 12_plan_set_execution.py:")
# %run 12_plan_set_execution.py
print("\n")
# Out:
# Executing 12_plan_set_execution.py:
# Example projects folder: c:\GH\ras-commander_workspace\examples\example_projects
# Found zip file: c:\GH\ras-commander_workspace\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Balde Eagle Creek'
# Project 'Balde Eagle Creek' already exists. Deleting existing folder...
# Existing folder for project 'Balde Eagle Creek' has been deleted.
# Successfully extracted project 'Balde Eagle Creek' to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Available plans:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
#
# Available geometries:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
#
# Copied c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p01 to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
# Updated short identifier in c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
# Updated C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.prj with new plan p03
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 3, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Copied 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g01' to 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g02'.
# Copied 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g01.hdf' to 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g02.hdf'.
# Updated C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.prj with new geometry file g02
# Updated geometry entries:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# Current geometry DataFrame within the function:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# Geometry for plan 03 set to 02
# Updated plan DataFrame:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path geom_number
# 0             None         NaN
# 1             None         NaN
# 2             None          02
# Updated project file with new geometry for plan 03
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 3, Flow entries: 2, Unsteady entries: 1, Geometry entries: 2
#
# Copied c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p01 to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p04
# Updated short identifier in c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p04
# Updated C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.prj with new plan p04
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 4, Flow entries: 2, Unsteady entries: 1, Geometry entries: 2
#
# Copied 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g01' to 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g03'.
# Copied 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g01.hdf' to 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g03.hdf'.
# Updated C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.prj with new geometry file g03
# Updated geometry entries:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# Current geometry DataFrame within the function:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# Geometry for plan 04 set to 03
# Updated plan DataFrame:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path geom_number
# 0             None         NaN
# 1             None         NaN
# 2             None         NaN
# 3             None          03
# Updated project file with new geometry for plan 04
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 4, Flow entries: 2, Unsteady entries: 1, Geometry entries: 3
#
# Copied c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p01 to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p05
# Updated short identifier in c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p05
# Updated C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.prj with new plan p05
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 5, Flow entries: 2, Unsteady entries: 1, Geometry entries: 3
#
# Copied 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g01' to 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g04'.
# Copied 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g01.hdf' to 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g04.hdf'.
# Updated C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.prj with new geometry file g04
# Updated geometry entries:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
# Current geometry DataFrame within the function:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
# Geometry for plan 05 set to 04
# Updated plan DataFrame:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
# 4          05  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path geom_number
# 0             None         NaN
# 1             None         NaN
# 2             None         NaN
# 3             None         NaN
# 4             None          04
# Updated project file with new geometry for plan 05
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 5, Flow entries: 2, Unsteady entries: 1, Geometry entries: 4
#
# Copied c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p01 to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p06
# Updated short identifier in c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p06
# Updated C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.prj with new plan p06
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 6, Flow entries: 2, Unsteady entries: 1, Geometry entries: 4
#
# Copied 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g01' to 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g05'.
# Copied 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g01.hdf' to 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g05.hdf'.
# Updated C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.prj with new geometry file g05
# Updated geometry entries:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
# 4          05  c:\GH\ras-commander_workspace\examples\example...
# Current geometry DataFrame within the function:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
# 4          05  c:\GH\ras-commander_workspace\examples\example...
# Geometry for plan 06 set to 05
# Updated plan DataFrame:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
# 4          05  c:\GH\ras-commander_workspace\examples\example...
# 5          06  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path geom_number
# 0             None         NaN
# 1             None         NaN
# 2             None         NaN
# 3             None         NaN
# 4             None         NaN
# 5             None          05
# Updated project file with new geometry for plan 06
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 6, Flow entries: 2, Unsteady entries: 1, Geometry entries: 5
#
# Copied c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p01 to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p07
# Updated short identifier in c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.p07
# Updated C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.prj with new plan p07
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 7, Flow entries: 2, Unsteady entries: 1, Geometry entries: 5
#
# Copied 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g01' to 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g06'.
# Copied 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g01.hdf' to 'c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.g06.hdf'.
# Updated C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek\BaldEagle.prj with new geometry file g06
# Updated geometry entries:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
# 4          05  c:\GH\ras-commander_workspace\examples\example...
# 5          06  c:\GH\ras-commander_workspace\examples\example...
# Current geometry DataFrame within the function:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
# 4          05  c:\GH\ras-commander_workspace\examples\example...
# 5          06  c:\GH\ras-commander_workspace\examples\example...
# Geometry for plan 07 set to 06
# Updated plan DataFrame:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
# 4          05  c:\GH\ras-commander_workspace\examples\example...
# 5          06  c:\GH\ras-commander_workspace\examples\example...
# 6          07  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path geom_number
# 0             None         NaN
# 1             None         NaN
# 2             None         NaN
# 3             None         NaN
# 4             None         NaN
# 5             None         NaN
# 6             None          06
# Updated project file with new geometry for plan 07
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 7, Flow entries: 2, Unsteady entries: 1, Geometry entries: 6
#
# Created plan set:
#   plan_number geom_number
# 0          03          02
# 1          04          03
# 2          05          04
# 3          06          05
# 4          07          06
#
# Executing plan set in parallel
# Adjusted max_workers to 3 based on the number of plans: 5
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 7, Flow entries: 2, Unsteady entries: 1, Geometry entries: 6
#
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 7, Flow entries: 2, Unsteady entries: 1, Geometry entries: 6
#
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 7, Flow entries: 2, Unsteady entries: 1, Geometry entries: 6
#
# Worker 1 executing plan 03
# Worker 2 executing plan 04
# Worker 3 executing plan 05
# Setting num_cores to 2 in Plan c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 2]\BaldEagle.p04
# Setting num_cores to 2 in Plan c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 1]\BaldEagle.p03
# Setting num_cores to 2 in Plan c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 3]\BaldEagle.p05
# Updated c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 2]\BaldEagle.p04 with 2 cores.
# Updated c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 1]\BaldEagle.p03 with 2 cores.
# Updated c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 3]\BaldEagle.p05 with 2 cores.
# Set number of cores to 2 for plan: 03
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 1]\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 1]\BaldEagle.p03"
# Set number of cores to 2 for plan: 04
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 2]\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 2]\BaldEagle.p04"
# Set number of cores to 2 for plan: 05
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 3]\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 3]\BaldEagle.p05"
# HEC-RAS execution completed for plan: 04
# Total run time for plan 04: 189.25 seconds
# Completed: Plan 04 in worker 2
# Worker 2 executing plan 06
# Setting num_cores to 2 in Plan c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 2]\BaldEagle.p06
# Updated c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 2]\BaldEagle.p06 with 2 cores.
# Set number of cores to 2 for plan: 06
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 2]\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 2]\BaldEagle.p06"
# HEC-RAS execution completed for plan: 03
# Total run time for plan 03: 189.71 seconds
# Completed: Plan 03 in worker 1
# Worker 1 executing plan 07
# Setting num_cores to 2 in Plan c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 1]\BaldEagle.p07
# Updated c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 1]\BaldEagle.p07 with 2 cores.
# Set number of cores to 2 for plan: 07
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 1]\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 1]\BaldEagle.p07"
# HEC-RAS execution completed for plan: 05
# Total run time for plan 05: 190.94 seconds
# Completed: Plan 05 in worker 3
# HEC-RAS execution completed for plan: 06
# Total run time for plan 06: 33.04 seconds
# Completed: Plan 06 in worker 2
# HEC-RAS execution completed for plan: 07
# Total run time for plan 07: 33.02 seconds
# Completed: Plan 07 in worker 1
# Final destination for computed results: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Computed]
# Error moving results from c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 1] to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Computed]: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\GH\\ras-commander_workspace\\examples\\example_projects\\Balde Eagle Creek [Worker 1]'
# Error moving results from c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Worker 2] to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [Computed]: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\GH\\ras-commander_workspace\\examples\\example_projects\\Balde Eagle Creek [Worker 2]'
#
# Execution Results:
# Plan 04: Successful
# Plan 03: Successful
# Plan 05: Successful
# Plan 06: Successful
# Plan 07: Successful
#
# Plan set execution results:
#   plan_number geom_number  execution_success
# 0          03          02               True
# 1          04          03               True
# 2          05          04               True
# 3          06          05               True
# 4          07          06               True

# %%
# wait 10 seconds
time.sleep(10)

# %%
print("Executing 13_multiple_project_operations.py:")
# %run 13_multiple_project_operations.py
print("\n")
# Out:
# Executing 13_multiple_project_operations.py:
# Example projects folder: c:\GH\ras-commander_workspace\examples\example_projects
# Found zip file: c:\GH\ras-commander_workspace\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Balde Eagle Creek'
# Project 'Balde Eagle Creek' already exists. Deleting existing folder...
# Existing folder for project 'Balde Eagle Creek' has been deleted.
# Successfully extracted project 'Balde Eagle Creek' to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek
# ----- RasExamples Extracting Project -----
# Extracting project 'Muncie'
# Successfully extracted project 'Muncie' to c:\GH\ras-commander_workspace\examples\example_projects\Muncie
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: Muncie-----
# Plan entries: 3, Flow entries: 1, Unsteady entries: 1, Geometry entries: 3
#
# Available plans in Bald Eagle Creek project:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          03  c:\GH\ras-commander_workspace\examples\example...
# 2          04  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
# 2             None
#
# Available plans in Muncie project:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          03  c:\GH\ras-commander_workspace\examples\example...
# 2          04  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
# 2             None
#
# Example 1: Cloning plans with custom short identifiers
# Copied c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p01 to c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p02
# Updated short identifier in c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p02
# Updated C:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.prj with new plan p02
#
# -----Initialization complete for project: Muncie-----
# Plan entries: 4, Flow entries: 1, Unsteady entries: 1, Geometry entries: 3
#
# Copied c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p01 to c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p05
# Updated short identifier in c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p05
# Updated C:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.prj with new plan p05
#
# -----Initialization complete for project: Muncie-----
# Plan entries: 5, Flow entries: 1, Unsteady entries: 1, Geometry entries: 3
#
# Created new plan 02 in Bald Eagle Creek project
# Created new plan 05 in Muncie project
#
# Example 2: Setting geometry for the new plans
# Current geometry DataFrame within the function:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          04  c:\GH\ras-commander_workspace\examples\example...
# Geometry for plan 02 set to 01
# Updated plan DataFrame:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
# 4          05  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path geom_number
# 0             None         NaN
# 1             None          01
# 2             None         NaN
# 3             None         NaN
# 4             None         NaN
# Updated project file with new geometry for plan 02
#
# -----Initialization complete for project: Muncie-----
# Plan entries: 5, Flow entries: 1, Unsteady entries: 1, Geometry entries: 3
#
# Current geometry DataFrame within the function:
#   geom_number                                          full_path
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          04  c:\GH\ras-commander_workspace\examples\example...
# Geometry for plan 05 set to 01
# Updated plan DataFrame:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
# 4          05  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path geom_number
# 0             None         NaN
# 1             None         NaN
# 2             None         NaN
# 3             None         NaN
# 4             None          01
# Updated project file with new geometry for plan 05
#
# -----Initialization complete for project: Muncie-----
# Plan entries: 5, Flow entries: 1, Unsteady entries: 1, Geometry entries: 3
#
# Set geometry for plan 02 in Bald Eagle Creek project
# Set geometry for plan 05 in Muncie project
#
# Example 3: Updating unsteady flow parameters
# Updated Computation Interval to 2MIN
# Updated Output Interval to 30MIN
# Updated Mapping Interval to 1HOUR
# Applied modifications to c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p02
# Updated Computation Interval to 2MIN
# Updated Output Interval to 30MIN
# Updated Mapping Interval to 1HOUR
# Applied modifications to c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p05
# Updated unsteady flow parameters for both projects
#
# Example 4: Executing plans for both projects simultaneously in separate compute folders
# Setting num_cores to 2 in Plan 02
# Setting num_cores to 2 in Plan 05
# Updated c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p05 with 2 cores.
# Updated c:\GH\ras-commander_workspace\examples\example_projects\Muncie\Muncie.p02 with 2 cores.
#
# -----Initialization complete for project: Muncie-----
# Plan entries: 5, Flow entries: 1, Unsteady entries: 1, Geometry entries: 3
#
#
# -----Initialization complete for project: Muncie-----
# Plan entries: 5, Flow entries: 1, Unsteady entries: 1, Geometry entries: 3
#
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\compute_muncie\Muncie.prj" "c:\GH\ras-commander_workspace\examples\example_projects\compute_muncie\Muncie.p05"
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\compute_bald_eagle\Muncie.prj" "c:\GH\ras-commander_workspace\examples\example_projects\compute_bald_eagle\Muncie.p02"
# HEC-RAS execution completed for plan: 05
# Total run time for plan 05: 11.52 seconds
# HEC-RAS execution completed for plan: 02
# Total run time for plan 02: 11.54 seconds
# Execution results:
# Plan 02 execution: Successful
# Plan 05 execution: Successful
#
# Example 5: Getting results paths
# Plan DataFrame:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
# 4          05  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# Results file for Plan number 02 does not exist.
# Plan DataFrame:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
# 2          03  c:\GH\ras-commander_workspace\examples\example...
# 3          04  c:\GH\ras-commander_workspace\examples\example...
# 4          05  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# Results file for Plan number 05 does not exist.
# No results found for Bald Eagle Creek plan 02
# No results found for Muncie plan 05
#
# Note: The original project folders can now be edited while the compute operations are running in separate folders.

# %%
# wait 10 seconds
time.sleep(10)

# %%
print("Executing xx_edge_cases.py:")
# %run xx_edge_cases.py
print("\n")
# Out:
# Executing xx_edge_cases.py:
# Example projects folder: c:\GH\ras-commander_workspace\examples\example_projects
# Found zip file: c:\GH\ras-commander_workspace\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Balde Eagle Creek'
# Project 'Balde Eagle Creek' already exists. Deleting existing folder...
# Existing folder for project 'Balde Eagle Creek' has been deleted.
# Successfully extracted project 'Balde Eagle Creek' to c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Available plans:
#   plan_number                                          full_path  \
# 0          01  c:\GH\ras-commander_workspace\examples\example...
# 1          02  c:\GH\ras-commander_workspace\examples\example...
#
#   HDF_Results_Path
# 0             None
# 1             None
#
# Example 1: Executing a single plan using compute_test_mode
# Deleted existing compute folder: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [SinglePlanTest]
# Starting the compute_test_mode...
# Creating the test folder: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [SinglePlanTest]...
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Getting plan entries...
# Retrieved plan entries successfully.
# Filtered plans to execute: ['01']
# Running selected plans sequentially...
# Error computing plan 01: name 'RasCommander' is not defined
# Total run time for plan 01: 0.00 seconds
# All selected plans have been executed.
# compute_test_mode completed.
# Execution of plan 01 completed using compute_test_mode
#
# Example 2: Executing a single plan using compute_parallel
# Adjusted max_workers to 1 based on the number of plans: 1
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Worker 1 executing plan 01
# Setting num_cores to 2 in Plan c:\GH\ras-commander_workspace\examples\example_projects\parallel_single_plan_result [Worker 1]\BaldEagle.p01
# Updated c:\GH\ras-commander_workspace\examples\example_projects\parallel_single_plan_result [Worker 1]\BaldEagle.p01 with 2 cores.
# Set number of cores to 2 for plan: 01
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\parallel_single_plan_result [Worker 1]\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\parallel_single_plan_result [Worker 1]\BaldEagle.p01"
# HEC-RAS execution completed for plan: 01
# Total run time for plan 01: 137.04 seconds
# Completed: Plan 01 in worker 1
# Final destination for computed results: c:\GH\ras-commander_workspace\examples\example_projects\parallel_single_plan_result
# Error moving results from c:\GH\ras-commander_workspace\examples\example_projects\parallel_single_plan_result [Worker 1] to c:\GH\ras-commander_workspace\examples\example_projects\parallel_single_plan_result: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\GH\\ras-commander_workspace\\examples\\example_projects\\parallel_single_plan_result [Worker 1]'
#
# Execution Results:
# Plan 01: Successful
# Parallel execution of single plan results:
# Plan 01: Successful
#
# Example 3: Executing a single plan using compute_test_mode with a string input
# Starting the compute_test_mode...
# Creating the test folder: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [SinglePlanTestString]...
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Getting plan entries...
# Retrieved plan entries successfully.
# Filtered plans to execute: ['02']
# Running selected plans sequentially...
# Error computing plan 02: name 'RasCommander' is not defined
# Total run time for plan 02: 0.00 seconds
# All selected plans have been executed.
# compute_test_mode completed.
# Execution of plan 02 completed using compute_test_mode with string input
#
# Example 4: Executing a single plan using compute_parallel with a string input
# Adjusted max_workers to 1 based on the number of plans: 1
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Worker 1 executing plan 01
# Setting num_cores to 2 in Plan c:\GH\ras-commander_workspace\examples\example_projects\parallel_single_plan_string_result [Worker 1]\BaldEagle.p01
# Updated c:\GH\ras-commander_workspace\examples\example_projects\parallel_single_plan_string_result [Worker 1]\BaldEagle.p01 with 2 cores.
# Set number of cores to 2 for plan: 01
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\GH\ras-commander_workspace\examples\example_projects\parallel_single_plan_string_result [Worker 1]\BaldEagle.prj" "c:\GH\ras-commander_workspace\examples\example_projects\parallel_single_plan_string_result [Worker 1]\BaldEagle.p01"
# HEC-RAS execution completed for plan: 01
# Total run time for plan 01: 129.57 seconds
# Completed: Plan 01 in worker 1
# Final destination for computed results: c:\GH\ras-commander_workspace\examples\example_projects\parallel_single_plan_string_result
# Error moving results from c:\GH\ras-commander_workspace\examples\example_projects\parallel_single_plan_string_result [Worker 1] to c:\GH\ras-commander_workspace\examples\example_projects\parallel_single_plan_string_result: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\GH\\ras-commander_workspace\\examples\\example_projects\\parallel_single_plan_string_result [Worker 1]'
#
# Execution Results:
# Plan 01: Successful
# Parallel execution of single plan (string input) results:
# Plan 01: Successful
#
# Example 5: Attempting to execute with an empty plan list
# Starting the compute_test_mode...
# Creating the test folder: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [EmptyPlanList]...
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Getting plan entries...
# Retrieved plan entries successfully.
# Running selected plans sequentially...
# Error computing plan 01: name 'RasCommander' is not defined
# Total run time for plan 01: 0.00 seconds
# Error computing plan 02: name 'RasCommander' is not defined
# Total run time for plan 02: 0.00 seconds
# All selected plans have been executed.
# compute_test_mode completed.
#
# Example 6: Attempting to execute with a non-existent plan number
# Starting the compute_test_mode...
# Creating the test folder: c:\GH\ras-commander_workspace\examples\example_projects\Balde Eagle Creek [NonExistentPlan]...
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Getting plan entries...
# Retrieved plan entries successfully.
# Filtered plans to execute: ['99']
# Running selected plans sequentially...
# All selected plans have been executed.
# compute_test_mode completed.
