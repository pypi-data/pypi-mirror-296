# %% [markdown]
# # Notebook for running all the examples in the examples folder
#
# This notebook also serves as a test of the ras_commander package using the HEC-RAS Project Examples provided by HEC.
#
# Example project names can be found in the example_projects.csv file after the examples are run.
#
# To use a different example, change the project name in the examples and run them directly or run this notebook.

# %% [markdown]
# The notebook format provides a convenient way to run all the examples to ensure that no features are broken after code revisions.

# %% [markdown]
# -----

# %% [markdown]
# This table is a valuable reference for formulating examples and anticipating script behavior.
#
# | Project           | Type     | Existing Numbers | Next Available |
# |-------------------|----------|-------------------|----------------|
# | Balde Eagle Creek | Plan     | 01, 02            | 03             |
# |                   | Flow     | 01, 02            | 03             |
# |                   | Unsteady | 02                | 01, 03         |
# |                   | Geometry | 01                | 02             |
# | Muncie            | Plan     | 01, 03, 04        | 02, 05         |
# |                   | Flow     | 01                | 02             |
# |                   | Unsteady | 01                | 02             |
# |                   | Geometry | 01, 02, 04        | 03, 05         |
#
# Notes:
# 1. For Balde Eagle Creek's Unsteady entries, 01 is available before 03. The library should use the lowest available number when creating new entries.
# 2. For Muncie's Plan entries, both 02 and 05 are available. The library should use 02 first.
# 3. For Muncie's Geometry entries, 03 is available before 05.
#
# When writing examples or scripts:
# 1. Use existing numbers when referencing current plans, flows, unsteady setups, or geometries.
# 2. When creating new entries (e.g., cloning), use the "Next Available" number and then increment for subsequent creations.
# 3. After operations that create new entries, verify that the ras object has been updated to reflect these changes.
#
# This approach will help ensure that examples run as expected and that we're always working with valid, up-to-date data in our scripts.

# %% [markdown]
# -----

# %% [markdown]
# # RAS-Commander (ras_commander) library examples

# %% [markdown]
# ### The Examples Below Have Been Tested and Verified.

# %% [markdown]
# -----

# %%
#!pip install pandas pathlib requests

# %%
# Example 1: Import and execute 01_project_initialization.py
print("Executing 01_project_initialization.py:")
# %run 01_project_initialization.py
print("\n")
# Out:
# Executing 01_project_initialization.py:
# Example projects folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects
# Found zip file: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Balde Eagle Creek'
# Successfully extracted project 'Balde Eagle Creek' to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek
# ----- RasExamples Extracting Project -----
# Extracting project 'BaldEagleCrkMulti2D'
# Successfully extracted project 'BaldEagleCrkMulti2D' to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\BaldEagleCrkMulti2D
# ----- RasExamples Extracting Project -----
# Extracting project 'Muncie'
# Successfully extracted project 'Muncie' to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Muncie
# Example Set 1: Using the default global 'ras' object
# -----------------------------------------------------
# Step 1: Initializing with global RAS instance
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
#
# --- Data for BaldEagle ---
# Project folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek
# PRJ file: C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.prj
# HEC-RAS executable: C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe
#
# Plan files:
#   plan_number                                          full_path  \
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
#   HDF_Results_Path
# 0             None
# 1             None
#
# Flow files:
#   flow_number                                          full_path
# 0          02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
# Unsteady flow files:
#   unsteady_number                                          full_path
# 0              02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
# Geometry files:
#   geom_number                                          full_path
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
# HDF entries:
# Empty DataFrame
# Columns: [plan_number, full_path, HDF_Results_Path]
# Index: []
# ----------------------------
#
#
# Step 2: Demonstrating accessing specific data
# Global RAS instance (Bald Eagle Creek) first plan file:
# plan_number                                                        01
# full_path           c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# HDF_Results_Path                                                 None
# Name: 0, dtype: object
#
# Step 3: Accessing All RAS Object Data
# Project Name: BaldEagle
# Project Folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek
# PRJ File: C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.prj
# HEC-RAS Executable Path: C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe
#
# Plan Files DataFrame:
#   plan_number                                          full_path  \
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
#   HDF_Results_Path
# 0             None
# 1             None
#
# Flow Files DataFrame:
#   flow_number                                          full_path
# 0          02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
# Unsteady Flow Files DataFrame:
#   unsteady_number                                          full_path
# 0              02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
# Geometry Files DataFrame:
#   geom_number                                          full_path
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
# HDF Entries DataFrame:
# Empty DataFrame
# Columns: [plan_number, full_path, HDF_Results_Path]
# Index: []
#
# Example Set 2: Using custom ras objects
# -----------------------------------------------------
# Step 1: Initializing multiple project instances
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagleDamBrk-----
# Plan entries: 11, Flow entries: 0, Unsteady entries: 10, Geometry entries: 10
#
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: Muncie-----
# Plan entries: 3, Flow entries: 1, Unsteady entries: 1, Geometry entries: 3
#
#
# Multi2D project data:
#
# --- Data for Muncie ---
# Project folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Muncie
# PRJ file: C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Muncie\Muncie.prj
# HEC-RAS executable: C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe
#
# Plan files:
#   plan_number                                          full_path  \
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          03  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 2          04  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
#   HDF_Results_Path
# 0             None
# 1             None
# 2             None
#
# Flow files:
#   flow_number                                          full_path
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
# Unsteady flow files:
#   unsteady_number                                          full_path
# 0              01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
# Geometry files:
#   geom_number                                          full_path
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 2          04  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
# HDF entries:
# Empty DataFrame
# Columns: [plan_number, full_path, HDF_Results_Path]
# Index: []
# ----------------------------
#
#
# Muncie project data:
#
# --- Data for Muncie ---
# Project folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Muncie
# PRJ file: C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Muncie\Muncie.prj
# HEC-RAS executable: C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe
#
# Plan files:
#   plan_number                                          full_path  \
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          03  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 2          04  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
#   HDF_Results_Path
# 0             None
# 1             None
# 2             None
#
# Flow files:
#   flow_number                                          full_path
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
# Unsteady flow files:
#   unsteady_number                                          full_path
# 0              01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
# Geometry files:
#   geom_number                                          full_path
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 2          04  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
# HDF entries:
# Empty DataFrame
# Columns: [plan_number, full_path, HDF_Results_Path]
# Index: []
# ----------------------------
#
#
# Step 2: Accessing specific data from custom ras objects
# Multi2D project first geometry file:
# geom_number                                                   01
# full_path      c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# Name: 0, dtype: object
#
# Muncie project first unsteady flow file:
# unsteady_number                                                   01
# full_path          c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# Name: 0, dtype: object
#
# Step 3: Accessing All RAS Object Data for Multi2D Project
# Project Name: Muncie
# Project Folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Muncie
# PRJ File: C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Muncie\Muncie.prj
# HEC-RAS Executable Path: C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe
#
# Plan Files DataFrame:
#   plan_number                                          full_path  \
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          03  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 2          04  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
#   HDF_Results_Path
# 0             None
# 1             None
# 2             None
#
# Flow Files DataFrame:
#   flow_number                                          full_path
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
# Unsteady Flow Files DataFrame:
#   unsteady_number                                          full_path
# 0              01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
# Geometry Files DataFrame:
#   geom_number                                          full_path
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 2          04  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
# HDF Entries DataFrame:
# Empty DataFrame
# Columns: [plan_number, full_path, HDF_Results_Path]
# Index: []
#
# Example of simplified import (not recommended for complex scripts)
# -----------------------------------------------------
# from ras_commander import *
# # This allows you to use all functions and classes without prefixes
# # For example: compute_plan() instead of RasCommander.compute_plan()
# # Note: This approach can lead to naming conflicts and is generally not recommended for larger scripts

# %% [markdown]
# -----

# %%
import time

# wait 10 seconds
time.sleep(10)

# %%
# Example 2: Import and execute 02_plan_operations.py
print("Executing 02_plan_operations.py:")
# %run 02_plan_operations.py
print("\n")
# Out:
# Executing 02_plan_operations.py:
# Example projects folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects
# Found zip file: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Balde Eagle Creek'
# Project 'Balde Eagle Creek' already exists. Deleting existing folder...
# Existing folder for project 'Balde Eagle Creek' has been deleted.
# Successfully extracted project 'Balde Eagle Creek' to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Initial plan files:
#   plan_number                                          full_path  \
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
#   HDF_Results_Path
# 0             None
# 1             None
#
# Step 1: Cloning a plan
# Copied c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.p01 to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
# Updated short identifier in c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
# Updated C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.prj with new plan p03
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 3, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# New plan created: 03
# Updated plan files:
#   plan_number                                          full_path  \
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 2          03  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
#   HDF_Results_Path
# 0             None
# 1             None
# 2             None
#
# Step 2: Cloning a geometry
# Copied 'c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.g01' to 'c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.g02'.
# Copied 'c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.g01.hdf' to 'c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.g02.hdf'.
# Updated C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.prj with new geometry file g02
# Updated geometry entries:
#   geom_number                                          full_path
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# New geometry created: 02
# Updated geometry files:
#   geom_number                                          full_path
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
# Step 3: Cloning an unsteady flow
# Copied c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.u02 to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.u01
# Copied c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.u02.hdf to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.u01.hdf
# Updated C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.prj with new unsteady flow file u01
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 3, Flow entries: 2, Unsteady entries: 2, Geometry entries: 2
#
# New unsteady flow created: 01
# Updated unsteady flow files:
#   unsteady_number                                          full_path
# 0              01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1              02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
# Step 4: Setting geometry for a plan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\02_plan_operations.py:140
#     137     print(ras.get_hdf_entries())
#     139 if __name__ == "__main__":
# --> 140     main()
#
# File ~\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\02_plan_operations.py:103, in main()
#     101 # Step 4: Set geometry for the cloned plan
#     102 print("Step 4: Setting geometry for a plan")
# --> 103 RasPlan.set_geom(new_plan_number, new_geo_number)
#     104 plan_path = RasPlan.get_plan_path(new_plan_number)
#     105 print(f"Updated geometry for plan {new_plan_number}")
#
# File ~\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\ras_commander\RasPlan.py:43, in RasPlan.set_geom(self, new_geom, ras_object)
#      40 geom_df = ras_obj.geom_df
#      42 if new_geom not in geom_df['geom_number']:
# ---> 43     raise ValueError(f"Geometry {new_geom} not found in project.")
#      45 self.geom = new_geom
#      46 geom_df.loc[geom_df['plan_number'] == self.plan_number, 'geom_number'] = new_geom
#
# ValueError: Geometry 02 not found in project.

# %% [markdown]
# -----

# %%
# wait 10 seconds
time.sleep(10)

# %%
# Example 3: Import and execute 03_geometry_operations.py
print("Executing 03_geometry_operations.py:")
# %run 03_geometry_operations.py
print("\n")
# Out:
# Executing 03_geometry_operations.py:
# Example projects folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects
# Found zip file: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Muncie'
# Project 'Muncie' already exists. Deleting existing folder...
# Existing folder for project 'Muncie' has been deleted.
# Successfully extracted project 'Muncie' to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Muncie
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: Muncie-----
# Plan entries: 3, Flow entries: 1, Unsteady entries: 1, Geometry entries: 3
#
# Initial plan files:
#   plan_number                                          full_path  \
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          03  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 2          04  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
#   HDF_Results_Path
# 0             None
# 1             None
# 2             None
#
# Step 1: Cloning a plan
# Copied c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Muncie\Muncie.p01 to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Muncie\Muncie.p02
# Updated short identifier in c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Muncie\Muncie.p02
# Updated C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Muncie\Muncie.prj with new plan p02
#
# -----Initialization complete for project: Muncie-----
# Plan entries: 4, Flow entries: 1, Unsteady entries: 1, Geometry entries: 3
#
# New plan created: 02
# Updated plan files:
#   plan_number                                          full_path  \
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 2          03  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 3          04  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
#   HDF_Results_Path
# 0             None
# 1             None
# 2             None
# 3             None
#
# Step 2: Cloning a geometry file and assigning it to the cloned plan
# Copied 'c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Muncie\Muncie.g01' to 'c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Muncie\Muncie.g03'.
# Copied 'c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Muncie\Muncie.g01.hdf' to 'c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Muncie\Muncie.g03.hdf'.
# Updated C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Muncie\Muncie.prj with new geometry file g03
# Updated geometry entries:
#   geom_number                                          full_path
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 2          03  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 3          04  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\03_geometry_operations.py:100
#      97         print(f"Failed to compute plan {new_plan_number}")
#      99 if __name__ == "__main__":
# --> 100     main()
#
# File ~\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\03_geometry_operations.py:65, in main()
#      63 print("Step 2: Cloning a geometry file and assigning it to the cloned plan")
#      64 new_geom_number = RasPlan.clone_geom("01")
# ---> 65 RasPlan.set_geom(new_plan_number, new_geom_number)
#      66 print(f"New geometry created: {new_geom_number} and assigned to plan {new_plan_number}")
#      67 print("Updated geometry files:")
#
# File ~\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\ras_commander\RasPlan.py:43, in RasPlan.set_geom(self, new_geom, ras_object)
#      40 geom_df = ras_obj.geom_df
#      42 if new_geom not in geom_df['geom_number']:
# ---> 43     raise ValueError(f"Geometry {new_geom} not found in project.")
#      45 self.geom = new_geom
#      46 geom_df.loc[geom_df['plan_number'] == self.plan_number, 'geom_number'] = new_geom
#
# ValueError: Geometry 03 not found in project.

# %% [markdown]
# -----

# %%
# wait 10 seconds
time.sleep(10)

# %%
# Example 4: Import and execute 04_unsteady_flow_operations.py
print("Executing 04_unsteady_flow_operations.py:")
# %run 04_unsteady_flow_operations.py
print("\n")
# Out:
# Executing 04_unsteady_flow_operations.py:
# Example projects folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects
# Found zip file: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Balde Eagle Creek'
# Project 'Balde Eagle Creek' already exists. Deleting existing folder...
# Existing folder for project 'Balde Eagle Creek' has been deleted.
# Successfully extracted project 'Balde Eagle Creek' to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Initial plan files:
#   plan_number                                          full_path  \
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
#   HDF_Results_Path
# 0             None
# 1             None
#
# Step 1: Cloning a plan
# Copied c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.p01 to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
# Updated short identifier in c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
# Updated C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.prj with new plan p03
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 3, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# New plan created: 03
# Updated plan files:
#   plan_number                                          full_path  \
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 2          03  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
#   HDF_Results_Path
# 0             None
# 1             None
# 2             None
#
# Step 3: Updating unsteady flow parameters individually
# Updated Simulation Date to 01JAN2023,0000,05JAN2023,2400
# Applied modifications to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
# Updated Computation Interval to 1MIN
# Applied modifications to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
# Updated Output Interval to 15MIN
# Applied modifications to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
# Updated parameters individually
#
# Step 4: Updating unsteady flow parameters in batch
# Updated Mapping Interval to 30MIN
# Applied modifications to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.p03
# Updated parameters in batch
#
# Step 5: Verifying changes
# Updated Simulation Date=01JAN2023,0000,05JAN2023,2400
# Updated Computation Interval=1MIN
# Updated Output Interval=15MIN
# Updated Mapping Interval=30MIN
#
# Step 6: Computing the updated plan
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.prj" "c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.p03"
# HEC-RAS execution completed for plan: 03
# Total run time for plan 03: 59.48 seconds
# Plan 03 computed successfully

# %% [markdown]
# -----

# %%
# wait 10 seconds
time.sleep(10)

# %%
# Example 5: Import and execute 05_utility_functions.py
print("Executing 05_utility_functions.py:")
# %run 05_utility_functions.py
print("\n")
# Out:
# Executing 05_utility_functions.py:
# Example projects folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects
# Found zip file: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Balde Eagle Creek'
# Project 'Balde Eagle Creek' already exists. Deleting existing folder...
# Existing folder for project 'Balde Eagle Creek' has been deleted.
# Successfully extracted project 'Balde Eagle Creek' to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Example 1: Getting plan path
# Path for plan 01 is: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.p01
#
# Example 2: Getting geometry path
# Path for geometry 01 is: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.g01
#
# Example 3: Getting unsteady flow path
# Unsteady number 01 not found in the updated unsteady entries.
# Path for unsteady flow 01 is: None
#
# Example 4: Getting project name
# Project name: BaldEagle

# %% [markdown]
# -----

# %%
# wait 10 seconds
time.sleep(10)

# %%
# Example 6: Import and execute 06_single_plan_execution.py
print("Executing 06_single_plan_execution.py:")
# %run 06_single_plan_execution.py
print("\n")
# Out:
# Executing 06_single_plan_execution.py:
# Example projects folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects
# Found zip file: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Balde Eagle Creek'
# Project 'Balde Eagle Creek' already exists. Deleting existing folder...
# Existing folder for project 'Balde Eagle Creek' has been deleted.
# Successfully extracted project 'Balde Eagle Creek' to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Available plans:
#   plan_number                                          full_path  \
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
#   HDF_Results_Path
# 0             None
# 1             None
#
# Example 1: Executing a single plan
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.prj" "c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.p01"
# HEC-RAS execution completed for plan: 01
# Total run time for plan 01: 149.98 seconds
# Plan 01 executed successfully
#
# Example 2: Executing a plan in a separate compute folder
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test\BaldEagle.prj" "c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test\BaldEagle.p02"
# HEC-RAS execution completed for plan: 02
# Total run time for plan 02: 8.16 seconds
# Plan 02 executed successfully in c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test
#
# Example 3: Getting results path
# Results file for Plan number 02 does not exist.
# No results found for plan 02

# %% [markdown]
# -----

# %%
# wait 10 seconds
time.sleep(10)

# %%
# Example 7: Import and execute 07_sequential_plan_execution.py
print("Executing 07_sequential_plan_execution.py:")
# %run 07_sequential_plan_execution.py
print("\n")
# Out:
# Executing 07_sequential_plan_execution.py:
# Removing existing folder: C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects
# Example projects folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects
# Found zip file: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Balde Eagle Creek'
# Successfully extracted project 'Balde Eagle Creek' to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Available plans:
#   plan_number                                          full_path  \
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
#   HDF_Results_Path
# 0             None
# 1             None
#
# Example 1: Sequential execution of all plans without clearing geompre files
# Starting the compute_test_mode...
# Creating the test folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [AllSequential]...
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Project file found: C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [AllSequential]\BaldEagle.prj
# Getting plan entries...
# Retrieved plan entries successfully.
# Running selected plans sequentially...
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [AllSequential]\BaldEagle.prj" "c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [AllSequential]\BaldEagle.p01"
# HEC-RAS execution completed for plan: 01
# Total run time for plan 01: 142.94 seconds
# Total run time for plan 01: 142.95 seconds
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [AllSequential]\BaldEagle.prj" "c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [AllSequential]\BaldEagle.p02"
# HEC-RAS execution completed for plan: 02
# Total run time for plan 02: 7.45 seconds
# Total run time for plan 02: 7.45 seconds
# All selected plans have been executed.
# compute_test_mode completed.
# Sequential execution of all plans completed without clearing geompre files
#
# Example 2: Sequential execution of specific plans with clearing geompre files
# Starting the compute_test_mode...
# Creating the test folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequentialClearGeompre]...
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Project file found: C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequentialClearGeompre]\BaldEagle.prj
# Getting plan entries...
# Retrieved plan entries successfully.
# Filtered plans to execute: ['01', '02']
# Processing geometry preprocessor files and core settings...
# No geometry preprocessor file found for: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequentialClearGeompre]\BaldEagle.p01
# Cleared geometry preprocessor files for c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequentialClearGeompre]\BaldEagle.p01
# Setting num_cores to 2 in Plan c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequentialClearGeompre]\BaldEagle.p01
# Updated c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequentialClearGeompre]\BaldEagle.p01 with 2 cores.
# Set max cores to 2 for c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequentialClearGeompre]\BaldEagle.p01
# No geometry preprocessor file found for: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequentialClearGeompre]\BaldEagle.p02
# Cleared geometry preprocessor files for c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequentialClearGeompre]\BaldEagle.p02
# Setting num_cores to 2 in Plan c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequentialClearGeompre]\BaldEagle.p02
# Updated c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequentialClearGeompre]\BaldEagle.p02 with 2 cores.
# Set max cores to 2 for c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequentialClearGeompre]\BaldEagle.p02
# Geometry preprocessor files and core settings processed successfully.
# Running selected plans sequentially...
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequentialClearGeompre]\BaldEagle.prj" "c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequentialClearGeompre]\BaldEagle.p01"
# HEC-RAS execution completed for plan: 01
# Total run time for plan 01: 136.78 seconds
# Total run time for plan 01: 136.78 seconds
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequentialClearGeompre]\BaldEagle.prj" "c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequentialClearGeompre]\BaldEagle.p02"
# HEC-RAS execution completed for plan: 02
# Total run time for plan 02: 6.89 seconds
# Total run time for plan 02: 6.89 seconds
# All selected plans have been executed.
# compute_test_mode completed.
# Sequential execution of specific plans completed with clearing geompre files
#
# Example 3: Clearing geompre files for specific plans
# No geometry preprocessor file found for: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.p01
# No geometry preprocessor file found for: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.p02
# Geometry preprocessor files cleared for specific plans
#
# Example 4: Clearing all geompre files
# Clearing all geometry preprocessor files in the project directory.
# No geometry preprocessor file found for: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.p01
# No geometry preprocessor file found for: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.p01.computeMsgs.txt
# No geometry preprocessor file found for: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.p01.comp_msgs.txt
# No geometry preprocessor file found for: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.p02
# No geometry preprocessor file found for: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.p02.computeMsgs.txt
# No geometry preprocessor file found for: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek\BaldEagle.prj
# All geometry preprocessor files cleared

# %% [markdown]
# -----

# %%
# wait 10 seconds
time.sleep(10)

# %%
# Example 8: Import and execute 08_parallel_execution.py
print("Executing 08_parallel_execution.py:")
# %run 08_parallel_execution.py
print("\n")
# Out:
# Executing 08_parallel_execution.py:
# Example projects folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects
# Found zip file: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Balde Eagle Creek'
# Project 'Balde Eagle Creek' already exists. Deleting existing folder...
# Existing folder for project 'Balde Eagle Creek' has been deleted.
# Successfully extracted project 'Balde Eagle Creek' to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Available plans:
#   plan_number                                          full_path  \
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
#   HDF_Results_Path
# 0             None
# 1             None
#
# Removing existing folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel
# Example 1: Parallel execution of all plans
# Adjusted max_workers to 2 based on the number of plans: 2
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Started worker thread 1
# Setting num_cores to 2 in Plan 01
# Started worker thread 2
# Setting num_cores to 2 in Plan 02
# Updated c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel [Worker 1]\BaldEagle.p01 with 2 cores.
# Updated c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel [Worker 2]\BaldEagle.p02 with 2 cores.
# Worker 1 executing plan 01
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel [Worker 1]\BaldEagle.prj" "c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel [Worker 1]\BaldEagle.p01"
# Worker 2 executing plan 02
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel [Worker 2]\BaldEagle.prj" "c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel [Worker 2]\BaldEagle.p02"
# HEC-RAS execution completed for plan: 02
# Total run time for plan 02: 9.44 seconds
# Completed: Plan 02 in worker 2
# HEC-RAS execution completed for plan: 01
# Total run time for plan 01: 145.33 seconds
# Completed: Plan 01 in worker 1
# Worker thread 1 has completed.
# Worker thread 2 has completed.
# Final destination for computed results: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel
# Error moving results from c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel [Worker 1] to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\Users\\billk\\Desktop\\AWS Webinar AI for HEC-RAS\\ras_commander\\ras_commander workspace6\\examples\\example_projects\\compute_test_parallel [Worker 1]'
# Moved results and removed worker folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel [Worker 2]
#
# Execution Results:
# Plan 02: Successful
# Plan 01: Successful
# Parallel execution of all plans results:
# Plan 02: Successful
# Plan 01: Successful
#
# Example 2: Parallel execution of specific plans
# Adjusted max_workers to 2 based on the number of plans: 2
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Started worker thread 1
# Setting num_cores to 2 in Plan 01
# Started worker thread 2
# Setting num_cores to 2 in Plan 02
# Updated c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel\specific_plans [Worker 1]\BaldEagle.p01 with 2 cores.
# Worker 1 executing plan 01
# Updated c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel\specific_plans [Worker 2]\BaldEagle.p02 with 2 cores.
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel\specific_plans [Worker 1]\BaldEagle.prj" "c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel\specific_plans [Worker 1]\BaldEagle.p01"
# Worker 2 executing plan 02
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel\specific_plans [Worker 2]\BaldEagle.prj" "c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel\specific_plans [Worker 2]\BaldEagle.p02"
# HEC-RAS execution completed for plan: 02
# Total run time for plan 02: 12.99 seconds
# Completed: Plan 02 in worker 2
# HEC-RAS execution completed for plan: 01
# Total run time for plan 01: 66.25 seconds
# Completed: Plan 01 in worker 1
# Worker thread 1 has completed.
# Worker thread 2 has completed.
# Final destination for computed results: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel\specific_plans
# Error moving results from c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel\specific_plans [Worker 1] to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel\specific_plans: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\Users\\billk\\Desktop\\AWS Webinar AI for HEC-RAS\\ras_commander\\ras_commander workspace6\\examples\\example_projects\\compute_test_parallel\\specific_plans [Worker 1]'
# Moved results and removed worker folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\compute_test_parallel\specific_plans [Worker 2]
#
# Execution Results:
# Plan 02: Successful
# Plan 01: Successful
# Parallel execution of specific plans results:
# Plan 02: Successful
# Plan 01: Successful
#
# Example 3: Getting results paths
# Results file for Plan number 01 does not exist.
# No results found for plan 01
# Results file for Plan number 02 does not exist.
# No results found for plan 02

# %% [markdown]
# -----

# %%
# wait 10 seconds
time.sleep(10)

# %%
# Example 9: Import and execute 09_specifying_plans.py
print("Executing 09_specifying_plans.py:")
# %run 09_specifying_plans.py
print("\n")
# Out:
# Executing 09_specifying_plans.py:
# Removing existing folder: C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects
# Example projects folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects
# Found zip file: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\Example_Projects_6_5.zip
# Loading project data from CSV...
# Loaded 66 projects from CSV, use list_categories() and list_projects() to explore them
# ----- RasExamples Extracting Project -----
# Extracting project 'Balde Eagle Creek'
# Successfully extracted project 'Balde Eagle Creek' to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek
#
# -----Initializing global 'ras' object via init_ras_project function-----
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Available plans:
#   plan_number                                          full_path  \
# 0          01  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
# 1          02  c:\Users\billk\Desktop\AWS Webinar AI for HEC-...
#
#   HDF_Results_Path
# 0             None
# 1             None
#
# Example 1: Sequential execution of specific plans (1 and 3)
# Starting the compute_test_mode...
# Creating the test folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequential]...
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Project file found: C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequential]\BaldEagle.prj
# Getting plan entries...
# Retrieved plan entries successfully.
# Filtered plans to execute: ['01', '03']
# Processing geometry preprocessor files and core settings...
# Setting num_cores to 6 in Plan c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequential]\BaldEagle.p01
# Updated c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequential]\BaldEagle.p01 with 6 cores.
# Set max cores to 6 for c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequential]\BaldEagle.p01
# Geometry preprocessor files and core settings processed successfully.
# Running selected plans sequentially...
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequential]\BaldEagle.prj" "c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [SpecificSequential]\BaldEagle.p01"
# HEC-RAS execution completed for plan: 01
# Total run time for plan 01: 25.57 seconds
# Total run time for plan 01: 25.57 seconds
# All selected plans have been executed.
# compute_test_mode completed.
# Sequential execution of specific plans completed
#
# Example 2: Parallel execution of specific plans
# Adjusted max_workers to 2 based on the number of plans: 2
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Started worker thread 1
# Setting num_cores to 2 in Plan 01
# Started worker thread 2
# Setting num_cores to 2 in Plan 02
# Updated c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\parallel_specific_results [Worker 1]\BaldEagle.p01 with 2 cores.
# Updated c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\parallel_specific_results [Worker 2]\BaldEagle.p02 with 2 cores.
# Worker 1 executing plan 01
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\parallel_specific_results [Worker 1]\BaldEagle.prj" "c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\parallel_specific_results [Worker 1]\BaldEagle.p01"
# Worker 2 executing plan 02
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\parallel_specific_results [Worker 2]\BaldEagle.prj" "c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\parallel_specific_results [Worker 2]\BaldEagle.p02"
# HEC-RAS execution completed for plan: 02
# Total run time for plan 02: 10.12 seconds
# Completed: Plan 02 in worker 2
# HEC-RAS execution completed for plan: 01
# Total run time for plan 01: 14.28 seconds
# Completed: Plan 01 in worker 1
# Worker thread 1 has completed.
# Worker thread 2 has completed.
# Final destination for computed results: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\parallel_specific_results
# Error moving results from c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\parallel_specific_results [Worker 1] to c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\parallel_specific_results: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\Users\\billk\\Desktop\\AWS Webinar AI for HEC-RAS\\ras_commander\\ras_commander workspace6\\examples\\example_projects\\parallel_specific_results [Worker 1]'
# Moved results and removed worker folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\parallel_specific_results [Worker 2]
#
# Execution Results:
# Plan 02: Successful
# Plan 01: Successful
# Parallel execution of specific plans results:
# Plan 02: Successful
# Plan 01: Successful
#
# Example 3: Execute all plans
# Starting the compute_test_mode...
# Creating the test folder: c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [AllPlans]...
#
# -----Initialization complete for project: BaldEagle-----
# Plan entries: 2, Flow entries: 2, Unsteady entries: 1, Geometry entries: 1
#
# Project file found: C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [AllPlans]\BaldEagle.prj
# Getting plan entries...
# Retrieved plan entries successfully.
# Filtered plans to execute: ['01', '02']
# Running selected plans sequentially...
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [AllPlans]\BaldEagle.prj" "c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [AllPlans]\BaldEagle.p01"
# HEC-RAS execution completed for plan: 01
# Total run time for plan 01: 6.69 seconds
# Total run time for plan 01: 6.69 seconds
# Running HEC-RAS from the Command Line:
# Running command: "C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe" -c "C:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [AllPlans]\BaldEagle.prj" "c:\Users\billk\Desktop\AWS Webinar AI for HEC-RAS\ras_commander\ras_commander workspace6\examples\example_projects\Balde Eagle Creek [AllPlans]\BaldEagle.p02"
# HEC-RAS execution completed for plan: 02
# Total run time for plan 02: 5.34 seconds
# Total run time for plan 02: 5.34 seconds
# All selected plans have been executed.
# compute_test_mode completed.
# Execution of all plans completed

# %% [markdown]
# -----
