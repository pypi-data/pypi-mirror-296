# %% [markdown]
# # Build EC4py package

# %%
import sys
from pathlib import Path
path_to_executable = "\"" + str(sys.executable) +  "\"" #must be used if there are any spaces in the path
print(path_to_executable)
# Out:
# "c:\Users\gusta\Documents\GitHub\NordicEC\EC4py\.venv\Scripts\python.exe"

# %% [markdown]
# Update all version files

# %%
import ver_update
ver_update.version_updated()
# Out:
# c:\Users\gusta\Documents\GitHub\NordicEC\EC4py\package.json
# Project Version 0.4.1
# {'build-system': {'requires': ['hatchling'], 'build-backend': 'hatchling.build'}, 'project': {'name': 'EC4py', 'version': '0.4.0', 'dependencies': ['nptdms', 'matplotlib', 'pathlib', 'scipy', 'numpy', 'pandas'], 'requires-python': '>=3.08', 'description': 'A package for data treatment of electrochemical data generated by EC4 DAQ. ', 'readme': 'README.md', 'keywords': ['python', 'EC4', 'tdms', 'Nordic Electorchemistry', 'electorchemistry'], 'classifiers': ['Development Status :: 4 - Beta', 'Operating System :: OS Independent', 'Programming Language :: Python'], 'authors': [{'name': 'Gustav Wiberg', 'email': 'g.wiberg@nordicec.com'}], 'maintainers': [{'name': 'Gustav Wiberg', 'email': 'g.wiberg@nordicec.com'}], 'license': {'file': 'LICENSE'}, 'urls': {'Homepage': 'https://nordicec.github.io/EC4py/', 'Documentation': 'https://nordicec.github.io/EC4py/', 'Repository': 'https://github.com/nordicec/EC4py', 'Issues': 'https://github.com/nordicec/EC4py', 'Changelog': 'https://github.com/nordicec/EC4py'}}, 'tool': {'setuptools': {'packages': {'find': {'where': ['src']}}}}}

# %%
from pathlib import Path
pr = str(Path().cwd().parent)
print (pr)
# !{path_to_executable} -m build {pr}
# Out:
# c:\Users\gusta\Documents\GitHub\NordicEC\EC4py

# %%
# !{path_to_executable} -m twine upload --config-file ../.pypirc ../dist/*
# Out:
# ERROR    InvalidConfiguration: [Errno 2] No such file or directory:
#          'C:\\Users\\gusta\\Documents\\GitHub\\NordicEC\\EC4py\\.pypirc'
